# %% [markdown]
# # APRS Optuna Sweep — Smoke Test
#
# Run this on a **T4 or A100** Colab runtime.
#
# Runtime → Change runtime type → GPU.

# %%
# 1. Check GPU
# !nvidia-smi --query-gpu=name,memory.total --format=csv,noheader

# %%
# 2. Clone repo
# !git clone https://github.com/hai-tri/aprs.git /content/aprs
# %cd /content/aprs

# %%
# 3. Install deps (pin torch to Colab's pre-installed CUDA build)
# !pip install -q -r requirements.txt --no-deps torch torchvision
# Verify torch sees CUDA
import torch; print(f"torch {torch.__version__}, CUDA {torch.cuda.is_available()}, GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'none'}")

# %%
# 4. HuggingFace auth (needed for gated Llama model)
from huggingface_hub import login
login()

# %%
# 5. Smoke test
# !python scripts/sweeps/sweep_optuna.py \
  --model llama \
  --smoke \
  --output_dir results/optuna_sweep_v2/smoke_test

# %%
# 6. Check results
import glob, pandas as pd
csvs = glob.glob("results/optuna_sweep_v2/smoke_test/*.csv")
if csvs:
    df = pd.read_csv(csvs[0])
    display(df)
else:
    print("No CSV output found.")
